# %% [markdown]
# # Exploratory Data Analysis on Breast Cancer Survival
#
#
#
#
# ![image-2.png](attachment:image-2.png)
#
#
#
#
#
#
#
# ## Overview
#
# Breast cancer is a type of cancer that forms or develops in the cells of the breast. Breast cancer can occur in both men and women, but it's far more common in women.
#
# The exact causes of breast cancer are not fully understood. However, several risk factors have been identified, including age, family history of breast cancer, specific genetic mutations (such as BRCA1 and BRCA2), hormonal factors (early menstruation, late menopause, hormone replacement therapy), obesity, alcohol consumption, and radiation exposure.
#
#
# ## Exploratory Data Analysis
#
# Understanding breast cancer survival data's underlying patterns, correlations, and characteristics requires exploratory data analysis (EDA). EDA assists researchers and analysts in gaining an understanding of the variables influencing breast cancer survival rates by analyzing and visualizing the data. The following are some significant justifications for the significance of EDA in terms of breast cancer survival:
#
# Understanding breast cancer survival data's underlying patterns, correlations, and characteristics requires exploratory data analysis (EDA). EDA assists researchers and analysts in gaining an understanding of the variables influencing breast cancer survival rates by analyzing and visualizing the data. The following are some significant justifications for the significance of EDA in terms of breast cancer survival:
# •	Understanding the data: EDA enables researchers to familiarize themselves with the dataset, its structure, and the variables at play. It aids in finding outliers, missing numbers, and other potential data quality problems that could affect the study.
#
# •	Identification of variables: EDA makes finding pertinent variables affecting breast cancer survivorship possible. It facilitates the selection of analysis-relevant variables, such as age, tumor size, tumor grade, hormone receptor status, lymph node involvement, etc.
#
# •	Patterns and relationships: EDA aids in identifying patterns and relationships in the data. For instance, it can reveal relationships between several factors, such as the connection between tumor size and survival rate. Identifying potential risk factors or protective variables that might affect survival results is also aided by this.
#
# •	Data visualization is made possible by EDA using a variety of plots and charts. Histograms, scatter plots, and box plots are examples of visual representations that can be used to spot distributions, trends, and potential outliers. Visualizations enhance comprehension by researchers and stakeholders and make it easier to share findings.
#
# •	EDA helps with feature engineering, which entails generating new derived variables or modifying old ones. By examining the data, researchers can find significant interactions or combinations of variables that could improve predicted accuracy.
#
# •	Data-driven decision-making: EDA offers insights based on solid evidence that can aid decision-making. It aids in understanding how many factors affect breast cancer survival, identifies patient populations at high risk, and directs the creation of individualized treatment plans.
#
# •	Creation of hypotheses: EDA makes it easier to develop theories to test. Researchers might create research questions and more focused studies to confirm or investigate potential causal linkages by examining the data and looking for patterns.
#
# Overall, EDA is crucial for understanding breast cancer survival data because it establishes the groundwork for additional statistical modeling, testing of hypotheses, and reaching meaningful conclusions. It enables researchers to make wise choices, unearths insightful information, and advance knowledge of breast cancer treatment and patient outcomes.
#
#
#
#
#
#
# ### Variables in the Dataset:
#
# 1)	Patient_ID: ID of the patient
#
# 2)	Age: The Age of the patient
#
# 3)	Gender: The gender of the patient
#
# 4)	Protein1, Protein2, Protein3, and Protein4: Expression levels
#
# 5)	Tumor_Stage: Breast cancer stage of the patient
#
# 6)	Histology: Infiltrating Ductal Carcinoma, Infiltration Lobular Carcinoma, and Mucinous Carcinoma
#
# 7)	ER status (Estrogen Receptor): Positive/Negative
#
# 8)	PR statuS (Progesterone Receptor): Positive/Negative
#
# 9)	HER2 status (Human Epidermal Growth Factor Receptor 2): Positive/Negative
#
# 10)	Surgery_type: Lumpectomy, Simple Mastectomy, Modified Radical Mastectomy, Other
#
# 11)	Date_of_Surgery: The date of Surgery
#
# 12)	Date_of_Last_Visit: The date of the last visit of the patient
#
# 13)	Patient_Status: Whether the patient is Alive or Dead

# %%
# Import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import our dataset

data = pd.read_csv(r'C:\Users\ASUS\Downloads\breast_cancer_data.csv')

# %%
# lets See what our first 5 dataframe look like

data.head()
# Out:
#    Unnamed: 0    Patient_ID   Age  Gender  Protein1  Protein2  Protein3  \
# 0           0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715
# 1           1  TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447
# 2           2  TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747
# 3           3  TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304
# 4           4  TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045
#
#    Protein4 Tumour_Stage                      Histology ER status PR status  \
# 0  0.273680          III  Infiltrating Ductal Carcinoma  Positive  Positive
# 1 -0.031505           II             Mucinous Carcinoma  Positive  Positive
# 2 -0.234260          III  Infiltrating Ductal Carcinoma  Positive  Positive
# 3  0.124270           II  Infiltrating Ductal Carcinoma  Positive  Positive
# 4 -0.311990           II  Infiltrating Ductal Carcinoma  Positive  Positive
#
#   HER2 status                 Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# 0    Negative  Modified Radical Mastectomy       15-Jan-17          19-Jun-17
# 1    Negative                   Lumpectomy       26-Apr-17          09-Nov-18
# 2    Negative                        Other       08-Sep-17          09-Jun-18
# 3    Negative  Modified Radical Mastectomy       25-Jan-17          12-Jul-17
# 4    Negative                        Other       06-May-17          27-Jun-19
#
#   Patient_Status
# 0          Alive
# 1           Dead
# 2          Alive
# 3          Alive
# 4           Dead

# %%
# dropping the 'Unnamed: 0' column

del data['Unnamed: 0']
data
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 336           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 337           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 338           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 339           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 340           NaN   NaN     NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage                      Histology ER status PR status  \
# 0            III  Infiltrating Ductal Carcinoma  Positive  Positive
# 1             II             Mucinous Carcinoma  Positive  Positive
# 2            III  Infiltrating Ductal Carcinoma  Positive  Positive
# 3             II  Infiltrating Ductal Carcinoma  Positive  Positive
# 4             II  Infiltrating Ductal Carcinoma  Positive  Positive
# ..           ...                            ...       ...       ...
# 336          NaN                            NaN       NaN       NaN
# 337          NaN                            NaN       NaN       NaN
# 338          NaN                            NaN       NaN       NaN
# 339          NaN                            NaN       NaN       NaN
# 340          NaN                            NaN       NaN       NaN
#
#     HER2 status                 Surgery_type Date_of_Surgery  \
# 0      Negative  Modified Radical Mastectomy       15-Jan-17
# 1      Negative                   Lumpectomy       26-Apr-17
# 2      Negative                        Other       08-Sep-17
# 3      Negative  Modified Radical Mastectomy       25-Jan-17
# 4      Negative                        Other       06-May-17
# ..          ...                          ...             ...
# 336         NaN                          NaN             NaN
# 337         NaN                          NaN             NaN
# 338         NaN                          NaN             NaN
# 339         NaN                          NaN             NaN
# 340         NaN                          NaN             NaN
#
#     Date_of_Last_Visit Patient_Status
# 0            19-Jun-17          Alive
# 1            09-Nov-18           Dead
# 2            09-Jun-18          Alive
# 3            12-Jul-17          Alive
# 4            27-Jun-19           Dead
# ..                 ...            ...
# 336                NaN            NaN
# 337                NaN            NaN
# 338                NaN            NaN
# 339                NaN            NaN
# 340                NaN            NaN
#
# [341 rows x 16 columns]

# %%
# Drop duplicates

data.drop_duplicates()
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 330  TCGA-A8-A085  44.0    MALE  0.732720   1.11170  -0.26952 -0.354920
# 331  TCGA-A1-A0SG  61.0  FEMALE -0.719470   2.54850  -0.15024  0.339680
# 332  TCGA-A2-A0EU  79.0  FEMALE  0.479400   2.05590  -0.53136 -0.188480
# 333  TCGA-B6-A40B  76.0  FEMALE -0.244270   0.92556  -0.41823 -0.067848
# 334           NaN   NaN     NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage                       Histology ER status PR status  \
# 0            III   Infiltrating Ductal Carcinoma  Positive  Positive
# 1             II              Mucinous Carcinoma  Positive  Positive
# 2            III   Infiltrating Ductal Carcinoma  Positive  Positive
# 3             II   Infiltrating Ductal Carcinoma  Positive  Positive
# 4             II   Infiltrating Ductal Carcinoma  Positive  Positive
# ..           ...                             ...       ...       ...
# 330           II  Infiltrating Lobular Carcinoma  Positive  Positive
# 331           II   Infiltrating Ductal Carcinoma  Positive  Positive
# 332            I   Infiltrating Ductal Carcinoma  Positive  Positive
# 333            I   Infiltrating Ductal Carcinoma  Positive  Positive
# 334          NaN                             NaN       NaN       NaN
#
#     HER2 status                 Surgery_type Date_of_Surgery  \
# 0      Negative  Modified Radical Mastectomy       15-Jan-17
# 1      Negative                   Lumpectomy       26-Apr-17
# 2      Negative                        Other       08-Sep-17
# 3      Negative  Modified Radical Mastectomy       25-Jan-17
# 4      Negative                        Other       06-May-17
# ..          ...                          ...             ...
# 330    Negative                        Other       01-Nov-19
# 331    Negative                   Lumpectomy       11-Nov-19
# 332    Positive                   Lumpectomy       21-Nov-19
# 333    Negative                   Lumpectomy       11-Nov-19
# 334         NaN                          NaN             NaN
#
#     Date_of_Last_Visit Patient_Status
# 0            19-Jun-17          Alive
# 1            09-Nov-18           Dead
# 2            09-Jun-18          Alive
# 3            12-Jul-17          Alive
# 4            27-Jun-19           Dead
# ..                 ...            ...
# 330          04-Mar-20           Dead
# 331          18-Jan-21           Dead
# 332          19-Feb-21           Dead
# 333          05-Jan-21           Dead
# 334                NaN            NaN
#
# [335 rows x 16 columns]

# %%
# Statistical analysis

data.describe()
# Out:
#               Age    Protein1    Protein2    Protein3    Protein4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean    58.886228   -0.029991    0.946896   -0.090204    0.009819
# std     12.961212    0.563588    0.911637    0.585175    0.629055
# min     29.000000   -2.340900   -0.978730   -1.627400   -2.025500
# 25%     49.000000   -0.358888    0.362173   -0.513748   -0.377090
# 50%     58.000000    0.006129    0.992805   -0.173180    0.041768
# 75%     68.000000    0.343598    1.627900    0.278353    0.425630
# max     90.000000    1.593600    3.402200    2.193400    1.629900

# %%
# number of rows and columns

data.shape
# Out:
# (341, 16)

# %%
 # inspect or Check our data information

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          334 non-null    object
#  1   Age                 334 non-null    float64
#  2   Gender              334 non-null    object
#  3   Protein1            334 non-null    float64
#  4   Protein2            334 non-null    float64
#  5   Protein3            334 non-null    float64
#  6   Protein4            334 non-null    float64
#  7   Tumour_Stage        334 non-null    object
#  8   Histology           334 non-null    object
#  9   ER status           334 non-null    object
#  10  PR status           334 non-null    object
#  11  HER2 status         334 non-null    object
#  12  Surgery_type        334 non-null    object
#  13  Date_of_Surgery     334 non-null    object
#  14  Date_of_Last_Visit  317 non-null    object
#  15  Patient_Status      321 non-null    object
# dtypes: float64(5), object(11)
# memory usage: 42.8+ KB

# %%
# check for missing values

data.isnull().sum()
# Out:
# Patient_ID             7
# Age                    7
# Gender                 7
# Protein1               7
# Protein2               7
# Protein3               7
# Protein4               7
# Tumour_Stage           7
# Histology              7
# ER status              7
# PR status              7
# HER2 status            7
# Surgery_type           7
# Date_of_Surgery        7
# Date_of_Last_Visit    24
# Patient_Status        20
# dtype: int64

# %%
# use forward fill to replace missing values

data = data.ffill(None)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3584\1392138940.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.ffill will be keyword-only.
#   data = data.ffill(None)

# %%
# double check

data.isnull().sum()
# Out:
# Patient_ID            0
# Age                   0
# Gender                0
# Protein1              0
# Protein2              0
# Protein3              0
# Protein4              0
# Tumour_Stage          0
# Histology             0
# ER status             0
# PR status             0
# HER2 status           0
# Surgery_type          0
# Date_of_Surgery       0
# Date_of_Last_Visit    0
# Patient_Status        0
# dtype: int64

# %%
# We can see the values for 'Age' column is shown as float, we need to covert these values to integer

data['Age'] = data['Age'].astype(int)

# %%
# Double check

data.head()
# Out:
#      Patient_ID  Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0  TCGA-D8-A1XD   36  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1  TCGA-EW-A1OX   43  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2  TCGA-A8-A079   69  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3  TCGA-D8-A1XR   56  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4  TCGA-BH-A0BF   56  FEMALE  0.221550   1.90680   0.52045 -0.311990
#
#   Tumour_Stage                      Histology ER status PR status HER2 status  \
# 0          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 1           II             Mucinous Carcinoma  Positive  Positive    Negative
# 2          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 3           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 4           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
#
#                   Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# 0  Modified Radical Mastectomy       15-Jan-17          19-Jun-17
# 1                   Lumpectomy       26-Apr-17          09-Nov-18
# 2                        Other       08-Sep-17          09-Jun-18
# 3  Modified Radical Mastectomy       25-Jan-17          12-Jul-17
# 4                        Other       06-May-17          27-Jun-19
#
#   Patient_Status
# 0          Alive
# 1           Dead
# 2          Alive
# 3          Alive
# 4           Dead

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Univariate Analysis

# %%
# What is the survival rate?

# create a visual that shows the distribution of Patients status 'Dead' and 'Alive'

plt.figure(figsize=(8,5))
plt.title('Survival Rate on Breast Cancer')
ax=sns.countplot(data=data, x='Patient_Status')
plt.xlabel('Patient_Status')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see 78.6% of breast cancer patients are still alive while 21.4% are dead. This could be as a result of early detection, advanced treatment, or individual factors such as age and overall health.
#
# #### Several factors might contribute to these survival disparities, including differences in tumor characteristics, hormone receptor status, treatment responses, and healthcare-seeking behaviors between women and men. Further research and analysis are necessary to understand these differences' underlying reasons and determine if they hold true in larger, more diverse populations.

# %%
# What Gender is most affected by Breast Cancer?

plt.figure(figsize=(8,5))
plt.title('Gender Count on Breast Cancer')
ax=sns.countplot(data=data, x='Gender')
plt.xlabel('Gender')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see Breast Cancer has no Gender. 98.8% of breast cancer patients are women; men are about 1.2%. This is because women are at a higher risk of developing breast cancer. Some factors responsible for this are:
#
# #### Hormonal factors: Women generally have higher estrogen and progesterone hormone levels than men.
#
# #### Genetic factors: Certain inherited gene mutations, such as BRCA1 and BRCA2, are mostly common in women than men.
#
# #### Breast tissue composition:  Women have more glandular tissue in their breasts than men. Glandular tissue contains more cells that can potentially develop cancerous mutations.

# %%
# What Tumor stage is common or higher among the patients?

plt.figure(figsize=(8,5))
plt.title('Tumor Stages of Breast Cancer')
ax=sns.countplot(x='Tumour_Stage', data=data)
plt.xlabel('Tumour_Stage')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: The tumor stage refers to the extent or progression of cancer within the body. Tumour stage II is higher, with 55.4%, than stage III (23.8%) and stage I (20.8%). Which means we have more patients with stage II breast cancer. When breast cancer is in stage II, it is either still contained within the breast or the tumor has only reached nearby lymph nodes.

# %%
# What is the distribution of Estrogen Receptor (ER) status among the patients?

plt.figure(figsize=(5,3))
plt.title('Distribution of Estrogen Receptor Status')
ax=sns.countplot(x='ER status', data=data)
plt.xlabel('ER status')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see that 100% of Breast Cancer are Estrogen Positive.  Which means the cancer cells grow in response to the Hormone Estrogen or express the Estrogen Receptor Protein (ER).
#
# #### Knowing the hormone receptor status of your cancer helps doctors decide how to treat it.

# %%
# What is the distribution of Progesterone Receptor (PR) status among the patients?

plt.figure(figsize=(5,5))
plt.title('Distribution of Progesterone Receptor Status')
ax=sns.countplot(x='PR status', data=data)
plt.xlabel('PR status')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see that 100% of Breast Cancer are Progesterone Positive.  Which means the cancer cells grow in response to the Hormone  Progesterone or express the  Progesterone Receptor Protein (PR).

# %%
# What is the distribution of Human Epidermal Growth Factor Receptor 2 (HER2) status among the patients?

plt.figure(figsize=(8,5))
plt.title('Distribution of Human Epidermal Growth Factor Receptor 2 Status')
ax=sns.countplot(x='HER2 status', data=data)
plt.xlabel('HER2 status')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see that 91.5% of Breast Cancer are Human Epidermal Growth Factor Receptor 2 Negative while 8.5% are Positive. Which means 91.5% of patients with breast cancer have a normal amount of this HER2 protein (HER2 Negative) while  8.5% express high amount or high level of HER2 Protein (HER2 Positive) thereby promoting the growth of cancer cells in the breast.

# %%
# What are the different histological types observed in the breast cancer patients?

plt.figure(figsize=(10,5))
plt.title('Distribution of Histology Types Among The Patients')
ax=sns.countplot(x='Histology', data=data)

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Histology, as used with breast cancer, is the study and analysis of microscopic features of breast tissue samples to identify the present kind and subtype of breast cancer. Diagnosis, categorization, and treatment planning for breast cancer patients depend heavily on histological analysis.
#
# #### We can see Infiltrating Ductal Carcinoma accounts for 70.4% of breast cancer found in patients. Infiltrating Ductal Carcinoma refers to the uncontrolled growth of cancerous cells originating from the ducts of the breast tissue. It is the most common form of invasive breast cancer.
#
# #### Infiltrating Lobular Carcinoma accounts for 26.1% of breast cancer found in patients. Infiltrating Lobular Carcinoma begins in the milk-producing glands (lobules) of the breast.
#
# #### Mucinous Carcinoma accounts for 3.55 of breast cancer found in patients . Mucinous carcinoma is a rare type of cancer that primarily develops in the breast. This form of breast cancer tends to be less aggressive.

# %%
# What surgery type is more common among these patients with breast cancer?

plt.figure(figsize=(10,5))
plt.title('Distribution of Surgery Type Among The Patients')
ax=sns.countplot(x='Surgery_type', data=data)

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: We can see that Other surgery type has a more significant number of 30.8%, followed by Modified Radical Mastectomy at 28%, Lumpectomy at 21.4%, and Simple Mastectomy at 19.6%.
#
# #### Breast cancer surgery type depends on the cancer stage and what option is best for the patient's situation.

# %%
# What is the age distribution of breast cancer cases?

sns.boxplot(data['Age'])
# Out:
# C:\Users\ASUS\anaconda3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
data['Age'].mode()
# Out:
# 0    59
# Name: Age, dtype: int32

# %%
data['Age'].mean()
# Out:
# 59.23753665689149

# %%
data['Age'].describe()
# Out:
# count    341.000000
# mean      59.237537
# std       13.055285
# min       29.000000
# 25%       49.000000
# 50%       59.000000
# 75%       68.000000
# max       90.000000
# Name: Age, dtype: float64

# %% [markdown]
# #### Observation: We can see the minimum age is at 29 and the maximum age is at 90.
# #### The plot shows a spread of data within the age range 49 to 68 years. Which means Patieints with breast cancer are within these age range. According to WebMD, Your risk for breast cancer increases as you age. About 80% of women diagnosed with breast cancer each year are aged 45 or older.

# %%
# Distribution of Protein1 Expression Level

plt.figure(figsize=(8,5))
plt.title('Distribution of Protein1 Expression Level')
sns.boxplot(data['Protein1'])
# Out:
# C:\Users\ASUS\anaconda3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Distribution of Protein1 Expression Level'}, xlabel='Protein1'>

# %%
data['Protein1'].mode()
# Out:
# 0   -0.24427
# Name: Protein1, dtype: float64

# %%
data['Protein1'].describe()
# Out:
# count    341.000000
# mean      -0.034390
# std        0.558586
# min       -2.340900
# 25%       -0.349620
# 50%        0.000000
# 75%        0.336530
# max        1.593600
# Name: Protein1, dtype: float64

# %% [markdown]
# #### Observation: We can see that the minimum value (-2.34) and maximum value (1.59) are outliers.
#
# #### It is skewed left.
#
# #### There is spread of data across values that fall within the range of -0.34 to 0.33.
#
# #### Negative expression values suggest that the protein is either not present or expressed at low levels in the breast cancer cells while Positive expression values indicates that the protein is present and expressed at varying levels in the breast cancer cells.

# %%
# Distribution of Protein2 Expression Level

plt.figure(figsize=(6,5))
plt.title('Distribution of Protein2 Expression Level')
sns.boxplot(data['Protein2'])
# Out:
# C:\Users\ASUS\anaconda3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Distribution of Protein2 Expression Level'}, xlabel='Protein2'>

# %%
data['Protein2'].describe()
# Out:
# count    341.000000
# mean       0.946458
# std        0.902209
# min       -0.978730
# 25%        0.372460
# 50%        0.953990
# 75%        1.609400
# max        3.402200
# Name: Protein2, dtype: float64

# %% [markdown]
# #### Observation: We can see the minimum value (-0.97) and maximum value (3.40).
#
# #### It is skewed right.
#
# #### We can see that there is a spread of data within the range of 0.37 to 1.60. Which means we have more distribution around the Positive expression values indicates that the protein is present and expressed at varying levels in the breast cancer cells. Higher positive values suggest a higher abundance or more robust protein expression within the breast cancer cells.

# %%
# Distribution of Protein3 Expression Level

plt.figure(figsize=(6,5))
plt.title('Distribution of Protein3 Expression Level')
sns.boxplot(data['Protein3'])
# Out:
# C:\Users\ASUS\anaconda3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Distribution of Protein3 Expression Level'}, xlabel='Protein3'>

# %%
data['Protein3'].describe()
# Out:
# count    341.000000
# mean      -0.096938
# std        0.580990
# min       -1.627400
# 25%       -0.513320
# 50%       -0.194890
# 75%        0.251210
# max        2.193400
# Name: Protein3, dtype: float64

# %% [markdown]
# #### Observation: The visualization reveals a spread of data ranging from -0.51 to 0.25. The spread of data suggests considerable variability in the expression of protein 3 among the breast cancer samples. Some samples show a downregulation of protein 3, while others exhibit an upregulation. This variability might be due to several factors, such as genetic variations, tumor heterogeneity.

# %%
# Distribution of Protein4 Expression Level

plt.figure(figsize=(6,5))
plt.title('Distribution of Protein4 Expression Level')
sns.boxplot(data['Protein4'])
# Out:
# C:\Users\ASUS\anaconda3\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Distribution of Protein4 Expression Level'}, xlabel='Protein4'>

# %%
data['Protein4'].describe()
# Out:
# count    341.000000
# mean       0.008225
# std        0.622643
# min       -2.025500
# 25%       -0.374070
# 50%        0.030815
# 75%        0.412550
# max        1.629900
# Name: Protein4, dtype: float64

# %% [markdown]
# #### Observation: The visualization reveals a spread of data ranging from -0.37 to 0.41.

# %% [markdown]
# ## Bivariate Analysis

# %%
# What is the ratio of Gender survivial on Breast Cancer?

plt.figure(figsize=(8,5))
plt.title('Gender Survival on Breast Cancer')
ax=sns.countplot(data=data, x='Gender', hue='Patient_Status')
plt.xlabel('Gender')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Obseravation: According to the analysis, approximately 77.7% of women with breast cancer are reported as alive, indicating a higher proportion of women surviving the disease. Conversely, 21.1% of women are reported dead, representing the portion of women who did not survive.
#
# #### On the other hand, the analysis shows that only 0.9% of men with breast cancer are reported as alive, indicating a significantly lower survival rate than women. Similarly, 0.3% of men are reported dead, representing the proportion of men who did not survive.
#
# #### These results imply that women with breast cancer have a significantly better chance of surviving than men, according to the dataset. It's crucial to remember that these percentages are specific to the dataset under consideration and might not accurately reflect general survival rates or the representativeness of the total community of women and men with breast cancer.

# %%
# How does different tumor stages influence the outcome of patients?

plt.figure(figsize=(8,5))
plt.title('Patient Status by Tumor Stage in Breast Cancer')
ax=sns.countplot(data=data, x='Tumour_Stage', hue='Patient_Status')
plt.xlabel('Tumour_Stage')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: From the visualization, we can see that
#
# #### Stage I Breast Cancer: Among patients with stage I breast cancer, 15.8% are alive, while 5.0% have unfortunately died. This suggests that most patients with stage I breast cancer have a positive outcome, with a higher percentage of survivors than deaths.
#
# #### Stage II Breast Cancer: In stage II breast cancer, the visualization reveals that 44.3% of patients are alive, while 11.1% have died. Although stage II has a higher percentage of deaths than stage I, it also has a significantly higher proportion of survivors. This indicates that while stage II breast cancer can result in more patient deaths, many patients still survive, leading to a higher overall survival rate than stage I.
#
# #### Stage III Breast Cancer: The data shows that 18.5% of stage III breast cancer patients are alive, and 5.3% have died. Stage III has a relatively lower percentage of survivors and deaths than Stage II. However, it's important to note that the provided data visualization does not provide the whole picture, and further analysis would be required to understand the factors influencing the differences in patient outcomes between stage II and stage III.
#
# #### The reason why stage II may have more deaths than stage III could be attributed to several factors. It is possible that stage II breast cancer, while generally considered less advanced than stage III, can still pose significant challenges and risks. The higher number of deaths in stage II could be due to various factors, including individual variations in tumor biology, aggressive subtypes, delayed diagnosis or treatment, or other patient-specific factors such as underlying health conditions or treatment response.

# %%
# Distribution of Tumor Stage between male and female patients

plt.figure(figsize=(8,5))
plt.title('Distribution of Tumor Stage between male and female patients')
ax=sns.countplot(data=data, x='Tumour_Stage', hue='Gender')
plt.xlabel('Tumour_Stage')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: Stage I Breast Cancer: The visualization indicates that only 20.8% of the patients with stage I breast cancer are female. Specific information regarding male patients with stage I breast cancer is not provided. This suggests that Stage I breast cancer is more commonly observed in females compared to males in the dataset.
#
# #### Stage II Breast Cancer: The data reveals that 54.5% of the patients with stage II breast cancer are female, while 0.9% are male. This indicates a significantly higher Stage II breast cancer prevalence among female patients than male patients in the dataset.
#
# #### Stage III Breast Cancer: The visualization shows that 23.5% of the patients with Stage III breast cancer are female, while 0.3% are male. This suggests a higher Stage III breast cancer occurrence among female patients than male patients in the dataset.
#
# #### To fully comprehend the trends seen, more research would be required, including taking age, genetic predisposition, or healthcare-seeking behavior into account.

# %%
# Distribution of histology types between male and female patients

plt.figure(figsize=(8,5))
plt.title('Distribution of histology types between male and female patients')
ax=sns.countplot(data=data, x='Histology', hue='Gender')
plt.xlabel('Histology')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: The visualization highlights the distribution of different histology types in breast cancer among male and female patients. The findings are as follows:
#
# #### Infiltrating Ductal Carcinoma: The visualization reveals that 16.8% of female patients had Infiltrating Ductal Carcinoma, while 0.6% of male patients had this histology type. This suggests that Infiltrating Ductal Carcinoma is more prevalent in females than males in the dataset.
#
# #### Infiltrating Lobular Carcinoma: The visualization shows that 25.5% of female patients had Infiltrating Lobular Carcinoma, while 0.6% of male patients had this histology type. This indicates a higher prevalence of Infiltrating Lobular Carcinoma among female patients than among males.
#
# #### Mucinous Carcinoma: The visualization indicates that 3.5% of female patients had Mucinous Carcinoma. Specific information regarding males with this histology type is not provided. This suggests that Mucinous Carcinoma is relatively less common than Infiltrating Ductal Carcinoma and Infiltrating Lobular Carcinoma in the dataset, particularly among females.
#
# #### In summary, the insight reveals gender-related differences in the distribution of specific histology types in breast cancer. Infiltrating Ductal Carcinoma and Infiltrating Lobular Carcinoma appear more prevalent in female patients, while Mucinous Carcinoma is seen in a smaller percentage of female patients.

# %%
# Distribution of surgery types between male and female patients

plt.figure(figsize=(8,6))
plt.title('Distribution of Surgery Type by Gender')
ax=sns.countplot(data=data, x='Surgery_type', hue='Gender')
plt.xlabel('Surgery_type')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: "Other" Surgery Type: The visualization reveals that a higher percentage of females (30.5%) underwent the "Other" surgery type compared to males (0.3%). This suggests that the "Other" surgery type is more commonly performed in females for cancer treatment.
#
# #### Modified Radical Mastectomy: The visualization indicates that a higher percentage of females (27.6%) underwent Modified Radical Mastectomy compared to males (0.6%). This implies that Modified Radical Mastectomy is predominantly chosen as a surgical option for females in the dataset.
#
# #### Lumpectomy: The visualization shows that only females (21.4%) had Lumpectomy surgery; no males in the dataset had this type of surgery. This suggests that Lumpectomy is primarily performed as a breast-conserving surgery in females.
#
# #### Simple Mastectomy: The visualization reveals that a significant percentage of females (19.4%) and males (0.3%) had surgery. This implies that Simple Mastectomy is performed in both genders, albeit with a higher prevalence in females.
#
# #### These insights suggest that the choice of surgery type in cancer treatment exhibits gender-related patterns. The visualization indicates variations in the distribution of different surgery types between females and males. Factors such as tumor characteristics, treatment guidelines, patient preferences, and cultural influences may contribute to these observed differences.

# %%
# What surgery type influences the survival rates of patients?

plt.figure(figsize=(8,5))
plt.title('Patient Survival on Breast Cancer Surgery Type')
ax=sns.countplot(data=data, x='Surgery_type', hue='Patient_Status')
plt.xlabel('Surgery_type')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
#  #### Observation: Based on the visualization, it can be observed that the "Other" surgery type has a higher proportion of patients who survived than the other two surgery types, namely Modified Radical Mastectomy and Simple Mastectomy.
#
# ####  A significant number of patients survived for the "Other" surgery type, indicating a positive outcome. Approximately 7.3% of patients who underwent this surgery did not survive the disease, representing a relatively lower proportion of deaths.
#
# #### In comparison, for Modified Radical Mastectomy, approximately 22.3% of patients survived, a relatively higher survival rate than other surgery types. On the other hand, 5.9% of patients who underwent this surgery type did not survive.
#
# #### Approximately 16.1% of patients survived for Simple Mastectomy, showing a slightly lower survival rate than Modified Radical Mastectomy. Similarly, the percentage of patients who did not survive after undergoing Simple Mastectomy was 3.5%.
#
# #### 16.7% of patients survived for Lumpectomy and 4.7% did not survive.

# %%
# Does the histology of breast cancer samples have a significant impact on patient survival outcomes?

plt.figure(figsize=(8,5))
plt.title('Patient Survival on Breast Cancer Histology')
ax=sns.countplot(data=data, x='Histology', hue='Patient_Status')
plt.xlabel('Histology')
plt.ylabel('Count of Patients')

# add percentages to the bars
total = float(len(data))
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 5
    ax.annotate(percentage, (x, y))
    
plt.show()

# %% [markdown]
# #### Observation: For infiltrating ductal carcinoma, the analysis shows that approximately 54.5% of patients with this histology are reported as alive, while 15.8% are reported as dead. This suggests that a majority of patients with infiltrating ductal carcinoma, as represented in the dataset, have survived.
#
# #### In contrast, for infiltrating lobular carcinoma, the analysis shows that approximately 21.8% of patients with this histology are reported as alive, while 4.7% are reported as dead. This indicates that a lower proportion of patients with infiltrating lobular carcinoma, as represented in the dataset, have survived compared to infiltrating ductal carcinoma.
#
# #### For Mucinous Carcinoma, the analysis shows that approximately 2.6% of patients with this histology are reported as alive, while 0.9% are reported as dead. This indicates that a lower proportion of patients with Mucinous Carcinoma, as represented in the dataset, have survived compared to infiltrating ductal carcinoma  and infiltrating lobular carcinoma.
#
# #### Based on the dataset, these findings suggest that infiltrating ductal carcinoma may generally be associated with a higher likelihood of patient survival than infiltrating lobular carcinoma and Mucinous Carcinoma. However, additional factors such as stage, treatment, and other patient characteristics may also contribute to these differences in survival rates between the two histology types.

# %% [markdown]
# ### Multivariate Analysis

# %%
# plot pairwise relationships between variables

sns.pairplot(data)

# %%
# pairwise correlation 

corel = data.corr()
corel
# Out:
#                Age  Protein1  Protein2  Protein3  Protein4
# Age       1.000000 -0.059819 -0.021790 -0.053792  0.089255
# Protein1 -0.059819  1.000000  0.237969 -0.124506  0.280848
# Protein2 -0.021790  0.237969  1.000000 -0.414215  0.088284
# Protein3 -0.053792 -0.124506 -0.414215  1.000000  0.066515
# Protein4  0.089255  0.280848  0.088284  0.066515  1.000000

# %%
# visual showing the correlation between different variables

corel = data.corr()
sns.heatmap(corel, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation: There is a moderate strong correlation between Protein1 and Protein2
# #### There is a moderate strong correlation between Protein1 and Protein4
